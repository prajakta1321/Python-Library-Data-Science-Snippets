# %%
import pandas as pd
summary = {
'Quarter': ['Q1', 'Q2', 'Q3', 'Q4'],
'Cost': [-23500, -34000, -57000, -32000],
'Revenue': [40000, 40000, 40000, 40000]
}

# %%
df = pd.DataFrame(summary)
print("First Dataset:\n",df)
# Out:
# First Dataset:
#    Quarter   Cost  Revenue
# 0      Q1 -23500    40000
# 1      Q2 -34000    40000
# 2      Q3 -57000    40000
# 3      Q4 -32000    40000

# %%
df['Total'] = df[['Cost', 'Revenue']].sum(axis=1)
df.loc['Sum'] = df[['Cost', 'Revenue', 'Total']].sum()
print("Second Dataset:\n",df)
# Out:
# Second Dataset:
#      Quarter      Cost   Revenue    Total
# 0        Q1  -23500.0   40000.0  16500.0
# 1        Q2  -34000.0   40000.0   6000.0
# 2        Q3  -57000.0   40000.0 -17000.0
# 3        Q4  -32000.0   40000.0   8000.0
# Sum     NaN -146500.0  160000.0  13500.0

# %%
# or df.loc['avg'] / 3
#df.loc['avg'] = df[:3].mean()

# %%
#print("Third Dataset:\n",df)

# %%
import pandas as pd

df = pd.read_csv('people.csv')

df.info()

print('fname:')
print(df['fname'])
print('------------')
print('age over 33:')
print(df['age'] > 33)
print('------------')
print('age over 33:')

myfilter = df['age'] > 33
print(df[myfilter])

# %%
df = pd.read_csv('multidelim.dat', skiprows=3, names=['a', 'b','c'],sep=' |:',engine='python')
print("dataframe:")
print(df)
print(df.head())

# %% [markdown]
# # SELECT, ADD AND DELETE COLUMNS IN A DATAFRAME

# %%
df = pd.DataFrame.from_dict(dict([('A',[1,2,3]),('B' [4,5,6])]),orient='index', columns=['one','two', 'three'])
print(df)

# %%
df['three'] = df['one'] * df['two']
df['flag'] = df['one'] > 2
print(df)

# %%
del df['two']
three = df.pop('three')
print(df)

# %%
df['foo'] = 'bar'
print(df)

# %%
df['one_trunc'] = df['one'][:2]
print(df)

# %% [markdown]
# # DATAFRAMES WITH SCATTERPLOTS

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas import read_csv
from pandas.plotting import scatter_matrix

myarray = np.array([[10,30,20], [50,40,60], [1000,2000,3000]])

rownames = ['apples', 'oranges', 'beer']
colnames = ['January', 'February', 'March']

# %%
mydf = pd.DataFrame(myarray, index=rownames, columns=colnames)

# %%
print(mydf)
# Out:
#          January  February  March
# apples        10        30     20
# oranges       50        40     60
# beer        1000      2000   3000

# %%
print(mydf.describe())
# Out:
#            January     February        March
# count     3.000000     3.000000     3.000000
# mean    353.333333   690.000000  1026.666667
# std     560.386771  1134.504297  1709.073823
# min      10.000000    30.000000    20.000000
# 25%      30.000000    35.000000    40.000000
# 50%      50.000000    40.000000    60.000000
# 75%     525.000000  1020.000000  1530.000000
# max    1000.000000  2000.000000  3000.000000

# %%
scatter_matrix(mydf)
plt.show()

# %% [markdown]
# # PANDAS DATAFRAMES AND HISTOGRAMS

# %%
df = pd.read_csv("Housing.csv")
print(df.head())
print(df.info())
print(df.describe())

import matplotlib.pyplot as plt
df.hist(bins=50, figsize=(20,15))
#save_fig("housing_histograms")
plt.show()

# %%
minimum_bdrms = df["bedrooms"].min()
median_bdrms = df["bedrooms"].median()
maximum_bdrms = df["bedrooms"].max()

print("minimum # of bedrooms:",minimum_bdrms)
print("median # of bedrooms:",median_bdrms)
print("maximum # of bedrooms:",maximum_bdrms)
print("")

print("median values:",df.median().values)
print("")

prices = df["price"]
print("first 5 prices:")

print(prices.head())
print("")

median_price = df["price"].median()

print("median price:",median_price)
print("")

corr_matrix = df.corr()

print("correlation matrix:")
print(corr_matrix["price"].sort_values(ascending=False))

# %% [markdown]
# # STANDARDIZING PANDAS DATAFRAME

# %%
from sklearn.preprocessing import StandardScaler
from pandas import read_csv
import numpy

# %%
url = 'https://goo.gl/bDdBiA'
names = ['preg','plas','pres','skin','test','mass','pedi','age','class']
dataframe = read_csv(url, names=names)
array = dataframe.values

# %%
X = array[:,0:8]
Y = array[:,8]
scaler = StandardScaler().fit(X)
rescaledX = scaler.transform(X)

# %%
# summarize transformed data
numpy.set_printoptions(precision=3)
print(rescaledX[0:5,:])
# Out:
# [[ 0.64   0.848  0.15   0.907 -0.693  0.204  0.468  1.426]
#  [-0.845 -1.123 -0.161  0.531 -0.693 -0.684 -0.365 -0.191]
#  [ 1.234  1.944 -0.264 -1.288 -0.693 -1.103  0.604 -0.106]
#  [-0.845 -0.998 -0.161  0.155  0.123 -0.494 -0.921 -1.042]
#  [-1.142  0.504 -1.505  0.907  0.766  1.41   5.485 -0.02 ]]

# %%
s1 = pd.Series(np.arange(5,10))
s1.dot(s1)
# Out:
# np.int64(255)

# %%
import pandas as pd
mydata = pd.DataFrame()

#Modify chunksize based on your requirements
for chunk in pd.read_csv('myfile.csv',iterator=True, chunksize=5000):
  mydata = pd.concat([mydata, chunk],ignore_index=True)
